# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
path = 'reviews'
artists = pd.read_csv(f'{path}/artists.csv')
content = pd.read_csv(f'{path}/content.csv')
genres = pd.read_csv(f'{path}/genres.csv')
labels = pd.read_csv(f'{path}/labels.csv')
reviews = pd.read_csv(f'{path}/reviews.csv')
years = pd.read_csv(f'{path}/years.csv')

# %%
dataset = pd.merge(artists, content, on='reviewid', how='outer')

# %%
dataset = pd.merge(dataset, genres, on='reviewid', how='outer')

# %%
dataset = pd.merge(dataset, labels, on='reviewid', how='outer')
dataset = pd.merge(dataset, reviews, on='reviewid', how='outer')
dataset = pd.merge(dataset, years, on='reviewid', how='outer')
dataset.dropna(axis=0, how='any', inplace=True)

# %%
dataset.genre.value_counts().plot( kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataset.score.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset.author_type.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataset.pub_year.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataset[['content', 'genre']].to_csv("data/content_dataset.csv", index=False)
